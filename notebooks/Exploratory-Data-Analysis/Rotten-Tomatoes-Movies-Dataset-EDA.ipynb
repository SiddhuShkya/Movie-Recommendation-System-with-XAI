# %%
# Importing Necessary Libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Loading the dataset
df = pd.read_csv("../../data/movie-raw-data-csv/rotten_tomatoes_movies.csv", low_memory=False)
df.sample(3).T
# Out:
#                                        56117   \
# id                    oru_indian_pranayakatha
# title                 Oru Indian Pranayakatha
# audienceScore                            60.0
# tomatoMeter                               NaN
# rating                                    NaN
# ratingContents                            NaN
# releaseDateTheaters                       NaN
# releaseDateStreaming                      NaN
# runtimeMinutes                            NaN
# genre                                   Drama
# originalLanguage                    Malayalam
# director                     Sathyan Anthikad
# writer                       Ikbal Kuttipuram
# boxOffice                                 NaN
# distributor                               NaN
# soundMix                                  NaN
#
#                                                          112446  \
# id                    marie_curie_the_courage_of_knowledge_2017
# title                                               Marie Curie
# audienceScore                                              55.0
# tomatoMeter                                                65.0
# rating                                                      NaN
# ratingContents                                              NaN
# releaseDateTheaters                                  2017-06-30
# releaseDateStreaming                                 2019-04-27
# runtimeMinutes                                            100.0
# genre                                 Biography, History, Drama
# originalLanguage                                French (France)
# director                                           Marie Noelle
# writer                                Marie Noelle,Andrea Stoll
# boxOffice                                               $124.9K
# distributor                                       Society Films
# soundMix                                                    NaN
#
#                                              68530
# id                                        v_subbotu
# title                 V subbotu (Innocent Saturday)
# audienceScore                                  18.0
# tomatoMeter                                     NaN
# rating                                          NaN
# ratingContents                                  NaN
# releaseDateTheaters                             NaN
# releaseDateStreaming                            NaN
# runtimeMinutes                                  NaN
# genre                                           NaN
# originalLanguage                                NaN
# director                         Aleksandr Mindadze
# writer                                          NaN
# boxOffice                                       NaN
# distributor                                     NaN
# soundMix                                        NaN
