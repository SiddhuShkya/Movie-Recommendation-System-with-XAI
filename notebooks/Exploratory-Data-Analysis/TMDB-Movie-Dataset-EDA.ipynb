# %%
# Importing Necessary Libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Dataset source : [link](https://www.kaggle.com/datasets/asaniczka/tmdb-movies-dataset-2023-930k-movies/data)

# %%
# Loading the dataset
df = pd.read_csv("../../data/movie-raw-data-csv/tmdb-movies.csv", low_memory=False)
df.sample(3).T
# Out:
#                                                                  966847  \
# id                                                               253092
# title                                  Spend the Holidays with Liberace
# vote_average                                                        0.0
# vote_count                                                            0
# status                                                         Released
# release_date                                                 1955-11-24
# revenue                                                               0
# runtime                                                              53
# adult                                                             False
# backdrop_path                          /rfs541bNr5PcyZPaf86S0CNG7AT.jpg
# budget                                                                0
# homepage                                                            NaN
# imdb_id                                                             NaN
# original_language                                                    en
# original_title                         Spend the Holidays with Liberace
# overview              Liberace invites us to his Thanksgiving musica...
# popularity                                                          0.6
# poster_path                            /xBeSqyfVGwIdrZphrLAiZHWj2ZQ.jpg
# tagline                                                             NaN
# genres                                                  Music, TV Movie
# production_companies                                                NaN
# production_countries                                                NaN
# spoken_languages                                                English
# keywords                                                            NaN
#
#                                                                  512159  \
# id                                                              1081058
# title                                        In Search of Marcus Garvey
# vote_average                                                        0.0
# vote_count                                                            0
# status                                                         Released
# release_date                                                 1981-01-01
# revenue                                                               0
# runtime                                                              28
# adult                                                             False
# backdrop_path                                                       NaN
# budget                                                                0
# homepage                                                            NaN
# imdb_id                                                             NaN
# original_language                                                    en
# original_title                               In Search of Marcus Garvey
# overview              Leon Brown, a young psychologist, find pamphle...
# popularity                                                          0.6
# poster_path                            /jzqBczl5yKGNL3F24dIgTeLIQuP.jpg
# tagline                                                             NaN
# genres                                                              NaN
# production_companies                                                NaN
# production_countries                                                NaN
# spoken_languages                                                    NaN
# keywords                                                            NaN
#
#                                                                  908868
# id                                                               617014
# title                         Life in a Zen Buddhist Monastery in Japan
# vote_average                                                        0.0
# vote_count                                                            0
# status                                                         Released
# release_date                                                 1959-01-01
# revenue                                                               0
# runtime                                                               9
# adult                                                             False
# backdrop_path                                                       NaN
# budget                                                                0
# homepage                                                            NaN
# imdb_id                                                             NaN
# original_language                                                    en
# original_title                Life in a Zen Buddhist Monastery in Japan
# overview              In Yokohama, novices wake up early in the Soto...
# popularity                                                          0.6
# poster_path                            /rOm086FyLG6t0MKfaMTqysIF3hu.jpg
# tagline                                                             NaN
# genres                                                      Documentary
# production_companies                                                NaN
# production_countries                                                NaN
# spoken_languages                                                    NaN
# keywords                                                            NaN

# %%
# The number of rows and columns in the dataset
print(f"Number of rows: {df.shape[0]}")
print(f"Number of columns: {df.shape[1]}")
# Out:
# Number of rows: 1269226
# Number of columns: 24

# %%
# Checking column Dtypes, non-null counts, and size
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1269226 entries, 0 to 1269225
# Data columns (total 24 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   id                    1269226 non-null  int64
#  1   title                 1269213 non-null  object
#  2   vote_average          1269226 non-null  float64
#  3   vote_count            1269226 non-null  int64
#  4   status                1269226 non-null  object
#  5   release_date          1023988 non-null  object
#  6   revenue               1269226 non-null  int64
#  7   runtime               1269226 non-null  int64
#  8   adult                 1269226 non-null  bool
#  9   backdrop_path         326879 non-null   object
#  10  budget                1269226 non-null  int64
#  11  homepage              132450 non-null   object
#  12  imdb_id               634125 non-null   object
#  13  original_language     1269226 non-null  object
#  14  original_title        1269213 non-null  object
#  15  overview              993031 non-null   object
#  16  popularity            1269226 non-null  float64
#  17  poster_path           843696 non-null   object
#  18  tagline               177555 non-null   object
#  19  genres                734541 non-null   object
#  20  production_companies  557098 non-null   object
#  21  production_countries  679126 non-null   object
#  22  spoken_languages      702425 non-null   object
#  23  keywords              328097 non-null   object
# dtypes: bool(1), float64(2), int64(5), object(16)
# memory usage: 223.9+ MB

# %%
# Displaying statistics of the dataset (Numerical columns)
df.describe(include='int').T
# Out:
#                 count           mean           std   min        25%       50%  \
# id          1269226.0  815727.241383  4.345462e+05   2.0  450560.25  826014.5
# vote_count  1269226.0      16.902560  3.014705e+02   0.0       0.00       0.0
# revenue     1269226.0  657105.513273  1.880353e+07 -12.0       0.00       0.0
# runtime     1269226.0      45.869586  6.125823e+01 -28.0       0.00      19.0
# budget      1269226.0  253695.971793  5.182517e+06   0.0       0.00       0.0
#
#                    75%           max
# id          1202821.75  1.527487e+06
# vote_count        1.00  3.449500e+04
# revenue           0.00  5.000000e+09
# runtime          87.00  1.440000e+04
# budget            0.00  1.000000e+09

# %%
# Displaying statistics of the dataset (Categorical columns)
df.describe(include=['object', 'category']).T
# Out:
#                         count   unique                               top  \
# title                 1269213  1083288                              Home
# status                1269226        6                          Released
# release_date          1023988    43221                        2006-01-01
# backdrop_path          326879   324016  /3CxwYgqGtJ6UEGfWUT0gMYCIlFP.jpg
# homepage               132450   123989    https://animation.geidai.ac.jp
# imdb_id                634125   631920                        tt32094375
# original_language     1269226      177                                en
# original_title        1269213  1118994                          Untitled
# overview               993031   962935
# poster_path            843696   838627  /wtoKLMm4UvkwvcSwO3XWcs1gJuF.jpg
# tagline                177555   170239                           English
# genres                 734541    14140                       Documentary
# production_companies   557098   220415                        Evil Angel
# production_countries   679126    10512          United States of America
# spoken_languages       702425     7268                           English
# keywords               328097   188609                        short film
#
#                          freq
# title                     172
# status                1232402
# release_date             3852
# backdrop_path             157
# homepage                  147
# imdb_id                    97
# original_language      690939
# original_title            125
# overview                 1220
# poster_path                54
# tagline                   271
# genres                 147454
# production_companies     3035
# production_countries   189859
# spoken_languages       251302
# keywords                10689
